# %%
# %load_ext autoreload
# %autoreload 2

# %%
import argparse
import copy
import gc
import json
import os
import pickle
from datetime import datetime
from functools import partial
import random

import numpy as np
import psutil
import torch
from torch import nn
from tqdm import tqdm
import wandb  # type: ignore

from bioplnn.models import SpatiallyEmbeddedClassifier
from bioplnn.utils import (
    initialize_dataloader,
    initialize_scheduler,
    manual_seed,
)

cabc_data_path = "./data/easy"
checkpoint_path = "./train/checkpoints"
dataset = "cabc"

# Torch setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_float32_matmul_precision("high")

BATCH_SIZE = 32

# %%
import sys
print(sys.prefix)
print(sys.executable)
# Out:
# /om2/user/jackking/conda/envs/superurop
# /om2/user/jackking/conda/envs/superurop/bin/python

# %%
def load_data(dataset, **args):
    train_loader, test_loader = initialize_dataloader(
        seed=42, dataset=dataset, **args
    )

    return train_loader, test_loader

# %%
train_loader, test_loader = load_data(dataset, batch_size=batch_size, root=cabc_data_path)
